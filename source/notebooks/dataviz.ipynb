# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = './data/IDRBT Cheque Image Dataset/300/Cheque 083654.tif'

img = cv2.imread(path)
plt.imshow(img)

# %%
path = './data/Kaggle Cheque Images/yolo x image/yolo x image/1.jpg'

img = cv2.imread(path)
plt.imshow(img)
